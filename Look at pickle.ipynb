# %%
import pandas as pd

# %%
new=pd.read_pickle("modern_romance.pkl")

# %%
new.head
# Out:
# <bound method NDFrame.head of                                    authors awards  \
# 0                           [Lana Popović]     []
# 1                             [Emma Chase]     []
# 2                          [Sierra Abrams]     []
# 3                              [Erin Watt]     []
# 4                          [Renee Carlino]     []
# 5                         [Kristen Ashley]     []
# 6                           [Sandra Brown]     []
# 7                                  [Tijan]     []
# 8                           [Mary Taranta]     []
# 9                        [Katharine McGee]     []
# 10                            [Tessa Dare]     []
# 11  [Emily Lloyd-Jones, Emily Lloyd-Jones]     []
# 12                       [Tiffany Pitcock]     []
# 13              [Susan Wiggs, Susan Wiggs]     []
# 14                      [Chelsea Bobulski]     []
# 15                           [Jessi Kirby]     []
# 16                              [F.C. Yee]     []
# ...

# %%
new['buy_link']
# Out:
# 0     /buy_buttons/12/follow?book_id=32051720&ref=x_...
# 1     /buy_buttons/12/follow?book_id=30176334&ref=x_...
# 2     /buy_buttons/12/follow?book_id=22892448&ref=x_...
# 3     /buy_buttons/12/follow?book_id=33807229&ref=x_...
# 4     /buy_buttons/12/follow?book_id=32620360&ref=x_...
# 5     /buy_buttons/12/follow?book_id=25165984&ref=x_...
# 6     /buy_buttons/12/follow?book_id=33296575&ref=x_...
# 7     /buy_buttons/12/follow?book_id=34853951&ref=x_...
# 8     /buy_buttons/12/follow?book_id=32333246&ref=x_...
# 9     /buy_buttons/13/follow?book_id=32711705&ref=x_...
# 10    /buy_buttons/12/follow?book_id=33259027&ref=x_...
# 11    /buy_buttons/12/follow?book_id=26309792&ref=x_...
# 12    /buy_buttons/12/follow?book_id=25876985&ref=x_...
# 13    /buy_buttons/12/follow?book_id=32600707&ref=x_...
# 14    /buy_buttons/12/follow?book_id=27258139&ref=x_...
# 15    /buy_buttons/12/follow?book_id=32703429&ref=x_...
# 16    /buy_buttons/12/follow?book_id=30116958&ref=x_...
# ...
