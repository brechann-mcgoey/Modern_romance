# %%
from bs4 import BeautifulSoup
import pandas as pd
import urllib
import requests
import codecs

# %%
session = requests.Session()
#HEAD requests ask for *just* the headers, which is all you need to grab

session.head("https://www.goodreads.com/book/show/9361589-the-night-circus")
response = requests.get("https://www.goodreads.com/book/reviews/9361589-the-night-circus?hide_last_page=true&amp;page=2")

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(codecs.getdecoder("unicode_escape")(response.text)[0],"lxml")

# %%
soup
# Out:
# <html><body><p>Element.update("reviews", "</p><div class="right bookMeta darkGreyText">
# <span class="smallText">
# (showing 31-60)
# </span>
# </div>
# <div data-book-reviews-page="2" id="bookReviewControls">
# <a class="uitext" href="#" id="span_class_actionlink_filter_span_tip_940" onclick="return false" style="cursor: pointer; "><span class="actionLink">filter</span></a><script>
# //<![CDATA[
# ...

# %%
soup.findAll('a', class_="next_page")[0]['onclick'].split("'")[1]
# Out:
# '/book/reviews/9361589-the-night-circus?hide_last_page=true&amp;page=3'

# %% [markdown]
# add try and loop over
#
# at some point at series thing

# %%
reviews = []
book_address="http://www.goodreads.com/book/show/9361589-the-night-circus"

while book_address:

    response = requests.get(book_address)

    if response.status_code == 200:
        print("")
        print("ok")
        soup = BeautifulSoup(codecs.getdecoder("unicode_escape")(response.text)[0],"lxml")
        
        reviews.append([review.findAll('span', class_='readable')[0].findAll('span')[-1].get_text() 
           for review in soup.findAll('div', class_="review")])
        

        try:
            book_address = "http://www.goodreads.com"+ soup.findAll('a', 
                            class_="next_page")[0]['onclick'].split("'")[1]
        except:
            book_address = ""
    else:
        print("reviews not found")
# Out:
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
# ...

# %%
reviews[1]
# Out:
# ['The Night Circus is like cake. Cake without frosting. Sure, cake is good, some people will even prefer dry, plain cake all by itself, but others, such as myself, need the sugary sweetness of frosting. Some may prefer the milder whip frosting. Or maybe even caramel or candy to put the final touches on our taste buds. Either way, plain cake, no matter how moist, is not for everyone.Yes, the writing is beautiful. Beyond beautiful. It\'s magnificent and breathtaking; the detailed scenery, the magic, the multitude of formidable descriptions of each tent inside this circus is all absolutely stunning. Furthermore, the approach taken to tell the story is excellent. We\'ve got the journey in past and present, walking alongside the characters their whole lives, in addition, we get our very own walk inside this resplendent circus which adds a truly delightful touch to the story. Unfortunately, this is the only aspect of the book I enjoyed: The writing. While I appreciate more literary books, 
# ...

# %%
book_reviews = [[review.findAll('span', class_='readable')[0].findAll('span')[-1].get_text() 
           for review in soup.findAll('div', class_="review")]]

# %%
book_review_users=

# %%
len(book_reviews[0])
# Out:
# 30

# %%
book_reviews
# Out:
# [['The Night Circus is like cake. Cake without frosting. Sure, cake is good, some people will even prefer dry, plain cake all by itself, but others, such as myself, need the sugary sweetness of frosting. Some may prefer the milder whip frosting. Or maybe even caramel or candy to put the final touches on our taste buds. Either way, plain cake, no matter how moist, is not for everyone.Yes, the writing is beautiful. Beyond beautiful. It\'s magnificent and breathtaking; the detailed scenery, the magic, the multitude of formidable descriptions of each tent inside this circus is all absolutely stunning. Furthermore, the approach taken to tell the story is excellent. We\'ve got the journey in past and present, walking alongside the characters their whole lives, in addition, we get our very own walk inside this resplendent circus which adds a truly delightful touch to the story. Unfortunately, this is the only aspect of the book I enjoyed: The writing. While I appreciate more literary books,
# ...

# %%
stringit = '''/reviews/30653853-the-upside-of-unrequited?authenticity_token=2q4Gqk6RB%2FaF69ZS8lXWwd8F1w7L893lmdDPxwHt1O%2BKsoM8bxXcyPO%2FCweOvb1ciao%2FgS4QeeHAjpjgNFQDCw%3D%3D\u0026amp;amp;hide_last_page=true\u0026amp;amp;page=3\u0026#39;, {asynchronous:true, evalScripts:true, method:\u0026#39;get\u0026#39;, parameters:\u0026#39;authenticity_token=\u0026#39; + encodeURIComponent(\u0026#39;9nBXyrKVOIjJ5V2dw3tDI+T9J2n23SQu9uAstlsNVnzja1TepsetkNA2N8xj4cNgt/8JtJ475cT6TMQ+sCcyyw==\u0026#39;)}); return false;\"\u003e3\u003c/a\u003e \u003ca href=\"#\" onclick=\"new Ajax.Request(\u0026#39;/book/reviews/30653853-the-upside-of-unrequited?authenticity_token=2q4Gqk6RB%2FaF69ZS8lXWwd8F1w7L893lmdDPxwHt1O%2BKsoM8bxXcyPO%2FCweOvb1ciao%2FgS4QeeHAjpjgNFQDCw%3D%3D\u0026amp;amp;hide_last_page=true\u0026amp;amp;page=4\u0026#39;, {asynchronous:true, evalScripts:true, method:\u0026#39;get\u0026#39;, parameters:\u0026#39;authenticity_token=\u0026#39; + encodeURIComponent(\u0026#39;moMRZm9ywlmlrQE+AdzGXH6N94Xk7YvNOpIZBDMzOgaPmBJyeyBXQbx+a2+hRkYfLY/ZWIwLSic2PvGM2BlesQ==\u0026#39;)}); return false;\"\u003e4\u003c/a\u003e \u003ca href=\"#\" onclick=\"new Ajax.Request(\u0026#39;/book/reviews/30653853-the-upside-of-unrequited?authenticity_token=2q4Gqk6RB%2FaF69ZS8lXWwd8F1w7L893lmdDPxwHt1O%2BKsoM8bxXcyPO%2FCweOvb1ciao%2FgS4QeeHAjpjgNFQDCw%3D%3D\u0026amp;amp;hide_last_page=true\u0026amp;amp;page=5\u0026#39;, {asynchronous:true, evalScripts:true, method:\u0026#39;get\u0026#39;, parameters:\u0026#39;authenticity_token=\u0026#39; + encodeURIComponent(\u0026#39;CPfLxz8eIdKWXsKWmGcb1ihA/rCay+yDTrsMjKBqsXId7MjTK0y0yo+NqMc4/ZuVe0LQbfItLWlCF+QES0DVxQ==\u0026#39;)}); return false;\"\u003e5\u003c/a\u003e \u003ca href=\"#\" onclick=\"new Ajax.Request(\u0026#39;/book/reviews/30653853-the-upside-of-unrequited?authenticity_token=2q4Gqk6RB%2FaF69ZS8lXWwd8F1w7L893lmdDPxwHt1O%2BKsoM8bxXcyPO%2FCweOvb1ciao%2FgS4QeeHAjpjgNFQDCw%3D%3D\u0026amp;amp;hide_last_page=true\u0026amp;amp;page=6\u0026#39;, {asynchronous:true, evalScripts:true, method:\u0026#39;get\u0026#39;, parameters:\u0026#39;authenticity_token=\u0026#39; + encodeURIComponent(\u0026#39;3hyeGCxTz5ZKGk/sjIw8r14SHkB5bTDe3op5y1kA5m3LB50MOAFajlPJJb0sFrzsDRAwnRGL8TTSJpFDsiqC2g==\u0026#39;)}); return false;\"\u003e6\u003c/a\u003e \u003ca href=\"#\" onclick=\"new Ajax.Request(\u0026#39;/book/reviews/30653853-the-upside-of-unrequited?authenticity_token=2q4Gqk6RB%2FaF69ZS8lXWwd8F1w7L893lmdDPxwHt1O%2BKsoM8bxXcyPO%2FCweOvb1ciao%2FgS4QeeHAjpjgNFQDCw%3D%3D\u0026amp;amp;hide_last_page=true\u0026amp;amp;page=7\u0026#39;, {asynchronous:true, evalScripts:true, method:\u0026#39;get\u0026#39;, parameters:\u0026#39;authenticity_token=\u0026#39; + encodeURIComponent(\u0026#39;OG10dID+2pK7F8qXdbhvonm0b4LJp3c1/soVm3vdzz0tdndglKxPiqLEoMbVIu/hKrZBX6FBtt/yZv0TkPerig==\u0026#39;)}); return false;\"\u003e7\u003c/a\u003e \u003ca href=\"#\" onclick=\"new Ajax.Request(\u0026#39;/book/reviews/30653853-the-upside-of-unrequited?authenticity_token=2q4Gqk6RB%2FaF69ZS8lXWwd8F1w7L893lmdDPxwHt1O%2BKsoM8bxXcyPO%2FCweOvb1ciao%2FgS4QeeHAjpjgNFQDCw%3D%3D\u0026amp;amp;hide_last_page=true\u0026amp;amp;page=8\u0026#39;, {asynchronous:true, evalScripts:true, method:\u0026#39;get\u0026#39;, parameters:\u0026#39;authenticity_token=\u0026#39; + encodeURIComponent(\u0026#39;DstqIc1aQ/X3lCveBJgij6FyBXOhCX/Zper43cbXIWsb0Gk12QjW7e5HQY+kAqLM8nArrsnvvjOpRhBVLf1F3A==\u0026#39;)}); return false;\"\u003e8\u003c/a\u003e \u003ca href=\"#\" onclick=\"new Ajax.Request(\u0026#39;/book/reviews/30653853-the-upside-of-unrequited?authenticity_token=2q4Gqk6RB%2FaF69ZS8lXWwd8F1w7L893lmdDPxwHt1O%2BKsoM8bxXcyPO%2FCweOvb1ciao%2FgS4QeeHAjpjgNFQDCw%3D%3D\u0026amp;amp;hide_last_page=true\u0026amp;amp;page=9\u0026#39;, {asynchronous:true, evalScripts:true, method:\u0026#39;get\u0026#39;, parameters:\u0026#39;authenticity_token=\u0026#39; + encodeURIComponent(\u0026#39;zgBBLpnEPBegVh9gSBrrZ/OTvwopiORkxdGKijQRMUvbG0I6jZapD7mFdTHogGskoJGR10FuJY7JfWIC3ztV/A==\u0026#39;)}); return false;\"\u003e9\u003c/a\u003e \u003cspan class=\"gap\"\u003e\u0026hellip;\u003c/span\u003e \u003ca class=\"next_page\" href=\"#\" onclick=\"new Ajax.Request(\u0026#39;/book/reviews/30653853-the-upside-of-unrequited?authenticity_token=2q4Gqk6RB%2FaF69ZS8lXWwd8F1w7L893lmdDPxwHt1O%2BKsoM8bxXcyPO%2FCweOvb1ciao%2FgS4QeeHAjpjgNFQDCw%3D%3D\u0026amp;amp;hide_last_page=true\u0026amp;amp;page=3\u0026#39;, {asynchronous:true, evalScripts:true, method:\u0026#39;get\u0026#39;, parameters:\u0026#39;authenticity_token=\u0026#39; + encodeURIComponent(\u0026#39;qMCTmuLIFLxsCVGiPiVFI8b2JAatXx/K7rcVGD/4w9K925CO9pqBpHXaO/Oev8VglfQK28W53iDiG/2Q1NKnZQ==\u0026#39;)}); return false;\"\u003enext »\u003c/a\u003e\u003c/div\u003e\n\n\u003c/div\u003e\n");'''

# %%
stringit
# Out:
# '/reviews/30653853-the-upside-of-unrequited?authenticity_token=2q4Gqk6RB%2FaF69ZS8lXWwd8F1w7L893lmdDPxwHt1O%2BKsoM8bxXcyPO%2FCweOvb1ciao%2FgS4QeeHAjpjgNFQDCw%3D%3D&amp;amp;hide_last_page=true&amp;amp;page=3&#39;, {asynchronous:true, evalScripts:true, method:&#39;get&#39;, parameters:&#39;authenticity_token=&#39; + encodeURIComponent(&#39;9nBXyrKVOIjJ5V2dw3tDI+T9J2n23SQu9uAstlsNVnzja1TepsetkNA2N8xj4cNgt/8JtJ475cT6TMQ+sCcyyw==&#39;)}); return false;">3</a> <a href="#" onclick="new Ajax.Request(&#39;/book/reviews/30653853-the-upside-of-unrequited?authenticity_token=2q4Gqk6RB%2FaF69ZS8lXWwd8F1w7L893lmdDPxwHt1O%2BKsoM8bxXcyPO%2FCweOvb1ciao%2FgS4QeeHAjpjgNFQDCw%3D%3D&amp;amp;hide_last_page=true&amp;amp;page=4&#39;, {asynchronous:true, evalScripts:true, method:&#39;get&#39;, parameters:&#39;authenticity_token=&#39; + encodeURIComponent(&#39;moMRZm9ywlmlrQE+AdzGXH6N94Xk7YvNOpIZBDMzOgaPmBJyeyBXQbx+a2+hRkYfLY/ZWIwLSic2PvGM2BlesQ==&#39;)}); return false;">4</a> <a href="#" onclick="new Ajax.Req
# ...
