# %% [markdown]
# Merge to the main pkl to update it with new ones

# %%
import pandas as pd

# %%
big=pd.read_pickle("bigger_romance.pkl")

# %%
new = pd.read_pickle("modern_romance_March31.pkl")

# %%
big.shape
# Out:
# (11018, 18)

# %%
new.shape
# Out:
# (100, 16)

# %%
big.head()
# Out:
#                authors                                             awards  \
# 40   [Jennifer Crusie]  [All About Romance (AAR) Annual Reader Poll fo...
# 45     [Rachel Gibson]  [OKRWA National Readers Choice Award for Singl...
# 59  [Kallypso Masters]                                                 []
# 61  [Kallypso Masters]                                                 []
# 66  [Kallypso Masters]                                                 []
#
#                   date                                        description  \
# 40   December 1st 2006  For Nina Askew, turning forty means freedom--f...
# 45    January 1st 1998  Georgeanne Howard leaves her fiancé at the alt...
# 59  December 13th 2012  Librarian's Note: This is an alternate cover f...
# 61   January 24th 2013  NOBODY'S PERFECT is the continuing story of Sa...
# 66  December 22nd 2013  When Marc d’Alessio first rescued the curvaceo...
#
# ...

# %%
new.head()
# Out:
#                 authors awards  \
# 0     [Sophie Kinsella]     []
# 1        [S. Jae-Jones]     []
# 2       [Ashley Poston]     []
# 3       [Penelope Ward]     []
# 4  [Tricia Levenseller]     []
#
#                                             buy_link                date  \
# 0  /buy_buttons/12/follow?book_id=35411583&ref=x_...  February 13th 2018
# 1  /buy_buttons/12/follow?book_id=30694168&ref=x_...   February 6th 2018
# 2  /buy_buttons/12/follow?book_id=35181314&ref=x_...  February 27th 2018
# 3  /buy_buttons/12/follow?book_id=37940505&ref=x_...  February 19th 2018
# 4  /buy_buttons/13/follow?book_id=36682619&ref=x_...  February 27th 2018
#
#                                          description        isbn  \
# 0  After being together for ten years, Sylvie and...  0399592881
# 1  Six months after the end of Wintersong, Liesl ...  1250129133
# 2  Seventeen-year-old Ana is a scoundrel by nurtu...  0062652850
# 3  From New York Times bestselling author Penelop...          NA
# ...

# %%
new.drop(['buy_link'], axis = 1, inplace = True)

# %%
new.drop(['description_bag'], axis = 1, inplace = True)

# %%
together=old.append(new)

# %%
together.head()
# Out:
#                authors                                             awards  \
# 40   [Jennifer Crusie]  [All About Romance (AAR) Annual Reader Poll fo...
# 45     [Rachel Gibson]  [OKRWA National Readers Choice Award for Singl...
# 59  [Kallypso Masters]                                                 []
# 61  [Kallypso Masters]                                                 []
# 66  [Kallypso Masters]                                                 []
#
#                   date                                        description  \
# 40   December 1st 2006  For Nina Askew, turning forty means freedom--f...
# 45    January 1st 1998  Georgeanne Howard leaves her fiancé at the alt...
# 59  December 13th 2012  Librarian's Note: This is an alternate cover f...
# 61   January 24th 2013  NOBODY'S PERFECT is the continuing story of Sa...
# 66  December 22nd 2013  When Marc d’Alessio first rescued the curvaceo...
#
# ...

# %%
together.tail()
# Out:
#                         authors  \
# 74  [Jane Austen, John  Coates]
# 75                 [Lizzy Ford]
# 76              [Joanna Bourne]
# 77               [Kim Harrison]
# 78                 [E.D. Baker]
#
#                                                awards                date  \
# 74                                                 []        May 3rd 1977
# 75                                                 []  December 29th 2015
# 76  [All About Romance (AAR) Annual Reader Poll fo...       June 1st 2010
# 77  [Goodreads Choice Award Nominee for Paranormal...  February 23rd 2010
# 78                                                 []        May 1st 2010
#
#                                           description        isbn  \
# 74  Left impoverished upon the death of her aunt, ...  0451075226
# 75  The secrets behind the Kingmaker Curse are sta...          NA
# 76  Marguerite de Fleurignac, once privileged aris...  0425235610
# ...

# %%
together.shape
# Out:
# (11018, 18)

# %%
together.to_pickle("bigger_romance.pkl")

# %%
old=pd.read_pickle("books_additional_columns.pkl")

# %%
old.head()
# Out:
#                       authors  \
# 0           [Jennifer Crusie]
# 1           [Sophie Kinsella]
# 2  [Susan Elizabeth Phillips]
# 3  [Susan Elizabeth Phillips]
# 4           [Nicholas Sparks]
#
#                                               awards                date  \
# 0  [All About Romance (AAR) Annual Reader Poll fo...    August 31st 2004
# 1                                                 []  December 27th 2005
# 2  [All About Romance (AAR) Annual Reader Poll fo...         August 2006
# 3  [RITA Award by Romance Writers of America for ...      March 5th 2002
# 4                                                 []       July 5th 2004
#
#                                          description        isbn  \
# 0  Minerva Dobbs knows that happily-ever-after is...  0312987854
# 1  Meet Emma Corrigan, a young woman with a huge ...  0440241901
# 2  You met quarterback Kevin Tucker in Nobody's B...  0060734566
# 3  What if a woman who knows nothing about sports...  0380776839
# ...

# %%
old_reviews=pd.read_pickle("old_list_reviews.pkl")

# %%
old_reviews.head()
# Out:
#                                         review_dates  \
# 0  [Jul 20, 2011, May 23, 2013, Jan 23, 2013, Feb...
# 1  [Apr 04, 2008, Nov 19, 2016, Apr 01, 2011, Feb...
# 2  [Dec 21, 2015, Jul 23, 2009, Oct 10, 2016, Aug...
# 3  [Jun 02, 2011, Jun 16, 2015, Jul 05, 2016, Mar...
# 4  [Dec 05, 2007, Jan 05, 2016, Aug 06, 2007, Oct...
#
#                                           review_ids  \
# 0  [review_186620674, review_622488584, review_51...
# 1  [review_19440490, review_1812918566, review_15...
# 2  [review_1475455775, review_64698454, review_17...
# 3  [review_173254551, review_1309273820, review_1...
# 4  [review_9978079, review_1496724905, review_415...
#
#                                         review_texts  \
# 0  [[After reading this, I don’t think I’ll eat C...
# 1  [[don't read this in public..especially if you...
# 2  [[\nThis book is just what I needed. Even thou...
# 3  [[Warning: This review deals with the book's c...
# ...

# %%
result = pd.concat([old, old_reviews], axis=1)

# %%
result.head()
# Out:
#                       authors  \
# 0           [Jennifer Crusie]
# 1           [Sophie Kinsella]
# 2  [Susan Elizabeth Phillips]
# 3  [Susan Elizabeth Phillips]
# 4           [Nicholas Sparks]
#
#                                               awards                date  \
# 0  [All About Romance (AAR) Annual Reader Poll fo...    August 31st 2004
# 1                                                 []  December 27th 2005
# 2  [All About Romance (AAR) Annual Reader Poll fo...         August 2006
# 3  [RITA Award by Romance Writers of America for ...      March 5th 2002
# 4                                                 []       July 5th 2004
#
#                                          description        isbn  \
# 0  Minerva Dobbs knows that happily-ever-after is...  0312987854
# 1  Meet Emma Corrigan, a young woman with a huge ...  0440241901
# 2  You met quarterback Kevin Tucker in Nobody's B...  0060734566
# 3  What if a woman who knows nothing about sports...  0380776839
# ...

# %%
result.tail()
# Out:
#                authors awards                date  \
# 3429     [Sandra Hill]     []     March 26th 2013
# 3430     [Sandra Hill]     []  November 27th 2012
# 3431     [Sandra Hill]     []     April 24th 2012
# 3432  [Deborah Bladon]     []    October 3rd 2014
# 3433  [Deborah Bladon]     []     August 8th 2014
#
#                                             description        isbn  \
# 3429  IS IT LUST? Ivak Sigurdsson is dead...well, so...  0062064630
# 3430  It’s not easy being a Vampire AngelNo one know...  0062064622
# 3431  SOME MEN ARE TOO BAD TO BE TRUE...Is he really...  0062064614
# 3432  Sitting next to a stranger on a flight from Bo...          NA
# 3433  Posing nude for the illustrious Noah Foster se...          NA
#
#                                                    link rating  \
# 3429  http://www.goodreads.com/book/show/15746149-ki...   4.13
# 3430  http://www.goodreads.com/book/show/13423390-ki...   3.93
# ...

# %%
result = result.iloc[:, :-1]

# %%
result.rename(columns={'reviwer_scores':'reviewer_scores'}, inplace=True)

# %%
result.head()
# Out:
#                       authors  \
# 0           [Jennifer Crusie]
# 1           [Sophie Kinsella]
# 2  [Susan Elizabeth Phillips]
# 3  [Susan Elizabeth Phillips]
# 4           [Nicholas Sparks]
#
#                                               awards                date  \
# 0  [All About Romance (AAR) Annual Reader Poll fo...    August 31st 2004
# 1                                                 []  December 27th 2005
# 2  [All About Romance (AAR) Annual Reader Poll fo...         August 2006
# 3  [RITA Award by Romance Writers of America for ...      March 5th 2002
# 4                                                 []       July 5th 2004
#
#                                          description        isbn  \
# 0  Minerva Dobbs knows that happily-ever-after is...  0312987854
# 1  Meet Emma Corrigan, a young woman with a huge ...  0440241901
# 2  You met quarterback Kevin Tucker in Nobody's B...  0060734566
# 3  What if a woman who knows nothing about sports...  0380776839
# ...

# %%
new=pd.read_pickle("second_romance.pkl")

# %%
new.head()
# Out:
#              authors                                             awards  \
# 0       [E.L. James]  [All About Romance (AAR) Annual Reader Poll fo...
# 1    [Jamie McGuire]  [Goodreads Choice Award Nominee for Best Young...
# 2      [Jane Austen]                                                 []
# 3  [Stephenie Meyer]  [Georgia Peach Book Award (2007), Buxtehuder B...
# 4   [Simone Elkeles]  [RITA Award by Romance Writers of America for ...
#
#                  date                                        description  \
# 0       May 25th 2011  When literature student Anastasia Steele goes ...
# 1       May 26th 2011  The new Abby Abernathy is a good girl. She doe...
# 2   October 10th 2000  “It is a truth universally acknowledged, that ...
# 3  September 6th 2006  About three things I was absolutely positive.F...
# 4  December 23rd 2008  A fresh, urban twist on the classic tale of st...
#
#          isbn                                               link rating  \
# ...

# %%
together=result.append(new)

# %%
together.head()
# Out:
#                       authors  \
# 0           [Jennifer Crusie]
# 1           [Sophie Kinsella]
# 2  [Susan Elizabeth Phillips]
# 3  [Susan Elizabeth Phillips]
# 4           [Nicholas Sparks]
#
#                                               awards                date  \
# 0  [All About Romance (AAR) Annual Reader Poll fo...    August 31st 2004
# 1                                                 []  December 27th 2005
# 2  [All About Romance (AAR) Annual Reader Poll fo...         August 2006
# 3  [RITA Award by Romance Writers of America for ...      March 5th 2002
# 4                                                 []       July 5th 2004
#
#                                          description  \
# 0  Minerva Dobbs knows that happily-ever-after is...
# 1  Meet Emma Corrigan, a young woman with a huge ...
# 2  You met quarterback Kevin Tucker in Nobody's B...
# 3  What if a woman who knows nothing about sports...
# 4  Set amid the austere beauty of the North Carol...
#
# ...

# %%
together.tail()
# Out:
#                         authors awards               date  \
# 95  [Kerstin Gier, Anthea Bell]     []   October 8th 2013
# 96             [Adler and Holt]     []  January 13th 2013
# 97        [Denise Grover Swank]     []    March 12th 2013
# 98                [M.J. Fields]     []      May 11th 2013
# 99             [Samantha Young]     []    August 9th 2013
#
#                                           description  \
# 95  Gwen has a destiny to fulfill, but no one will...
# 96  It’s official; Harrison Towers is engaged to M...
# 97  Scarlett Goodwin’s world is divided into Befor...
# 98  Mature New Adult/Adult novel - contains adult ...
# 99  Live young. Live hard. Love deep.Charley Redfo...
#
#                                       description_bag description_freq  \
# 95  [gwen, destiny, fulfill, one, tell, she’s, rec...              NaN
# 96  [it’s, official, harrison, towers, engaged, ma...              NaN
# ...

# %%
together.shape
# Out:
# (6638, 24)

# %%
unique=together.drop_duplicates(subset='title',keep='last')

# %%
unique.head()
# Out:
#                authors                                             awards  \
# 40   [Jennifer Crusie]  [All About Romance (AAR) Annual Reader Poll fo...
# 45     [Rachel Gibson]  [OKRWA National Readers Choice Award for Singl...
# 59  [Kallypso Masters]                                                 []
# 61  [Kallypso Masters]                                                 []
# 66  [Kallypso Masters]                                                 []
#
#                   date                                        description  \
# 40   December 1st 2006  For Nina Askew, turning forty means freedom--f...
# 45    January 1st 1998  Georgeanne Howard leaves her fiancé at the alt...
# 59  December 13th 2012  Librarian's Note: This is an alternate cover f...
# 61   January 24th 2013  NOBODY'S PERFECT is the continuing story of Sa...
# 66  December 22nd 2013  When Marc d’Alessio first rescued the curvaceo...
#
#                                       description_bag  \
# ...

# %%
unique.tail()
# Out:
#                         authors awards               date  \
# 95  [Kerstin Gier, Anthea Bell]     []   October 8th 2013
# 96             [Adler and Holt]     []  January 13th 2013
# 97        [Denise Grover Swank]     []    March 12th 2013
# 98                [M.J. Fields]     []      May 11th 2013
# 99             [Samantha Young]     []    August 9th 2013
#
#                                           description  \
# 95  Gwen has a destiny to fulfill, but no one will...
# 96  It’s official; Harrison Towers is engaged to M...
# 97  Scarlett Goodwin’s world is divided into Befor...
# 98  Mature New Adult/Adult novel - contains adult ...
# 99  Live young. Live hard. Love deep.Charley Redfo...
#
#                                       description_bag description_freq  \
# 95  [gwen, destiny, fulfill, one, tell, she’s, rec...              NaN
# 96  [it’s, official, harrison, towers, engaged, ma...              NaN
# ...

# %%
unique.drop(['reviews'], axis = 1, inplace = True)
# Out:
# /home/brechann/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
unique.head()
# Out:
#                authors                                             awards  \
# 40   [Jennifer Crusie]  [All About Romance (AAR) Annual Reader Poll fo...
# 45     [Rachel Gibson]  [OKRWA National Readers Choice Award for Singl...
# 59  [Kallypso Masters]                                                 []
# 61  [Kallypso Masters]                                                 []
# 66  [Kallypso Masters]                                                 []
#
#                   date                                        description  \
# 40   December 1st 2006  For Nina Askew, turning forty means freedom--f...
# 45    January 1st 1998  Georgeanne Howard leaves her fiancé at the alt...
# 59  December 13th 2012  Librarian's Note: This is an alternate cover f...
# 61   January 24th 2013  NOBODY'S PERFECT is the continuing story of Sa...
# 66  December 22nd 2013  When Marc d’Alessio first rescued the curvaceo...
#
# ...

# %%
unique.tail()
# Out:
#                         authors awards               date  \
# 95  [Kerstin Gier, Anthea Bell]     []   October 8th 2013
# 96             [Adler and Holt]     []  January 13th 2013
# 97        [Denise Grover Swank]     []    March 12th 2013
# 98                [M.J. Fields]     []      May 11th 2013
# 99             [Samantha Young]     []    August 9th 2013
#
#                                           description        isbn  \
# 95  Gwen has a destiny to fulfill, but no one will...          NA
# 96  It’s official; Harrison Towers is engaged to M...          NA
# 97  Scarlett Goodwin’s world is divided into Befor...  148265864X
# 98  Mature New Adult/Adult novel - contains adult ...          NA
# 99  Live young. Live hard. Love deep.Charley Redfo...          NA
#
#                                                  link num_ratings num_reviews  \
# 95  http://www.goodreads.com/book/show/17620267-em...
# 96  http://www.goodreads.com/book/show/16479452-sh...
# ...

# %%
unique.to_pickle("big_romance.pkl")
