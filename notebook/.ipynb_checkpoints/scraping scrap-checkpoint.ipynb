# %%
from scrape import *
import pandas as pd
from bs4 import BeautifulSoup

# %%
df=pd.DataFrame()

# %%
df.to_pickle

# %%
df = pd.DataFrame()
list_address="http://www.goodreads.com/genres/new_releases/romance"

while list_address:

    list_response = requests.get(list_address)

    if list_response.status_code == 200:
        print("")
        print("ok",list_address)
        soup = BeautifulSoup(list_response.text,"lxml")
        book_links = ["http://www.goodreads.com" + book.find("a")["href"] for book in soup.find_all("div",class_="coverWrapper")]
        
        
        try:
            list_address = "http://www.goodreads.com"+ soup.find('a',class_='next_page')['href']
        except:
            list_address = ""
    else:
        print("website not found")

    for num, link in enumerate(book_links):
     
        book_results = parse_page(link)
        print(link)
        
        df=df.append(pd.DataFrame(book_results),ignore_index=True)
# Out:
# ok http://www.goodreads.com/genres/new_releases/romance
# http://www.goodreads.com/book/show/30653853-the-upside-of-unrequited
# http://www.goodreads.com/book/show/30312700-alex-approximately
# http://www.goodreads.com/book/show/30724132-geekerella
# http://www.goodreads.com/book/show/28220678-twist
# http://www.goodreads.com/book/show/32860355-alex-and-eliza
# http://www.goodreads.com/book/show/31423196-defy-the-stars
# http://www.goodreads.com/book/show/27246123-the-thing-about-love
# http://www.goodreads.com/book/show/30163661-spindle-fire
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2847, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-01c1c29f389b>", line 24, in <module>
#     book_results = parse_page(link)
#   File "/Users/brechann/workspace/goodreads/scrape.py", line 79, in parse_page
#     soup = BeautifulSoup(webpage.text, "lxml")
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/bs4/__init__.py", line 228, in __init__
#     self._feed()
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/bs4/__init__.py", line 289, in _feed
#     self.builder.feed(self.markup)
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/bs4/builder/_lxml.py", line 250, in feed
#     self.parser.feed(markup)
#   File "src/lxml/parser.pxi", line 1217, in lxml.etree._FeedParser.feed (src/lxml/lxml.etree.c:113776)
#   File "src/lxml/parser.pxi", line 1339, in lxml.etree._FeedParser.feed (src/lxml/lxml.etree.c:113649)
#   File "src/lxml/parsertarget.pxi", line 147, in lxml.etree._TargetParserContext._handleParseResult (src/lxml/lxml.etree.c:130495)
#   File "src/lxml/parsertarget.pxi", line 135, in lxml.etree._TargetParserContext._handleParseResult (src/lxml/lxml.etree.c:130238)
#   File "src/lxml/lxml.etree.pyx", line 324, in lxml.etree._ExceptionContext._raise_if_stored (src/lxml/lxml.etree.c:12081)
#   File "src/lxml/saxparser.pxi", line 388, in lxml.etree._handleSaxTargetStartNoNs (src/lxml/lxml.etree.c:122716)
#   File "src/lxml/saxparser.pxi", line 403, in lxml.etree._callTargetSaxStart (src/lxml/lxml.etree.c:122913)
#   File "src/lxml/parsertarget.pxi", line 80, in lxml.etree._PythonSaxParserTarget._handleSaxStart (src/lxml/lxml.etree.c:129235)
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/bs4/builder/_lxml.py", line 145, in start
#     def start(self, name, attrs, nsmap={}):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 1795, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/IPython/core/ultratb.py", line 1092, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/IPython/core/ultratb.py", line 312, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/brechann/anaconda/lib/python3.5/inspect.py", line 1454, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/brechann/anaconda/lib/python3.5/inspect.py", line 1411, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/brechann/anaconda/lib/python3.5/inspect.py", line 671, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/brechann/anaconda/lib/python3.5/inspect.py", line 708, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/py/_apipkg.py", line 171, in __getattribute__
#     return getattr(getmod(), name)
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/py/_apipkg.py", line 155, in getmod
#     x = importobj(modpath, None)
#   File "/Users/brechann/anaconda/lib/python3.5/site-packages/py/_apipkg.py", line 48, in importobj
#     module = __import__(modpath, None, None, ['__doc__'])
#   File "<frozen importlib._bootstrap>", line 969, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 958, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 673, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 763, in get_code
#   File "<frozen importlib._bootstrap_external>", line 832, in get_data
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
df
# Out:
#                       authors awards             date  \
# 0          [Becky Albertalli]     []  April 11th 2017
# 1              [Jenn Bennett]     []   April 4th 2017
# 2             [Ashley Poston]     []   April 4th 2017
# 3  [Kylie Scott, Kylie Scott]     []  April 11th 2017
# 4        [Melissa de la Cruz]     []  April 11th 2017
# 5              [Claudia Gray]     []   April 4th 2017
# 6               [Julie James]     []  April 18th 2017
# 7              [Lexa Hillyer]         April 11th 2017
#
#                                          description        isbn  \
# 0  Seventeen-year-old Molly Peskin-Suso knows all...  0062348701
# 1  The one guy Bailey Rydell can’t stand is actua...  148147877X
# 2  Anything can happen once upon a con…When geek ...  1594749477
# 3  When his younger brother loses interest in onl...  1250083222
# 4  Their romance shaped a nation. The rest was hi...  1524739626
# 5  She’s a soldier.Noemi Vidal is seventeen years...  0316394033
# 6  Two undercover FBI agents can hide who they ar...  0425273776
# 7  A kingdom burns. A princess sleeps. This is no...          NA
#
#                                                 link  \
# 0  http://www.goodreads.com/book/show/30653853-th...
# 1  http://www.goodreads.com/book/show/30312700-al...
# 2  http://www.goodreads.com/book/show/30724132-ge...
# 3  http://www.goodreads.com/book/show/28220678-twist
# 4  http://www.goodreads.com/book/show/32860355-al...
# 5  http://www.goodreads.com/book/show/31423196-de...
# 6  http://www.goodreads.com/book/show/27246123-th...
# 7  http://www.goodreads.com/book/show/30163661-sp...
#
#                                                 page rating  \
# 0  <!DOCTYPE html>\n<html class="desktop">\n\n\n<...   4.17
# 1  <!DOCTYPE html>\n<html class="desktop">\n\n\n<...   4.07
# 2  <!DOCTYPE html>\n<html class="desktop">\n\n\n<...   4.15
# 3  <!DOCTYPE html>\n<html class="desktop">\n\n\n<...   3.98
# 4  <!DOCTYPE html>\n<html class="desktop">\n\n\n<...   3.72
# 5  <!DOCTYPE html>\n<html class="desktop">\n\n\n<...   4.12
# 6  <!DOCTYPE html>\n<html class="desktop">\n\n<he...    4.0
# 7  <!DOCTYPE html>\n<html class="desktop">\n\n\n<...   3.32
#
#                                         review_dates  \
# 0  [May 12, 2017, May 12, 2017, May 12, 2017, May...
# 1  [May 12, 2017, May 12, 2017, May 12, 2017, May...
# 2  [May 12, 2017, May 12, 2017, May 12, 2017, May...
# 3  [May 12, 2017, May 12, 2017, May 12, 2017, May...
# 4
# 5
# 6
# 7
#
#                                           review_ids  \
# 0  [review_1998467435, review_1997758994, review_...
# 1  [review_1998055552, review_1907935087, review_...
# 2  [review_1998509105, review_1952345977, review_...
# 3  [review_1642584644, review_1802394005, review_...
# 4
# 5
# 6
# 7
#
#                                         review_texts  \
# 0  [[3.5 Stars. Just like Simon Vs. The Homo Sapi...
# 1  [[3.5 Stars!], [3.75 STARS], [[ one thing the ...
# 2  [[4.5 stars! THIS BOOK, it's absolutely adorab...
# 3  [[just was not as good as the first.], [Lumber...
# 4
# 5
# 6
# 7
#
#                                       reviewer_names  \
# 0  [Sophia Jones, Kaitie, Ashley Peet, Azee, Tiff...
# 1  [Pehel , Laura, Erin, Love, Beck, Melissa, Mar...
# 2  [Giselle (onwednesdaysweread), Whitney, Alisa,...
# 3  [Tina, Olivia, Holly Hawk, Caraleigh Tackett, ...
# 4
# 5
# 6
# 7
#
#                                     reviewer_ratings  \
# 0  [liked it, really liked it, it was amazing, it...
# 1  [liked it, really liked it, liked it, it was a...
# 2  [it was amazing, really liked it, really liked...
# 3  [liked it, it was amazing, it was amazing, it ...
# 4
# 5
# 6
# 7
#
#                                      reviewer_scores  \
# 0  [3, 4, 5, 5, 5, 2, 4, 4, 3, 4, 5, 4, 4, 5, 5, ...
# 1  [3, 4, 3, 5, 5, 4, 5, 4, 3, 3, 5, 4, 4, 4, 4, ...
# 2  [5, 4, 4, 3, 5, 4, 5, 3, 5, 4, 5, 5, 5, 5, 4, ...
# 3  [3, 5, 5, 5, 3, 4, 3, 4, 5, 3, 4, 2, 4, 5, 4, ...
# 4
# 5
# 6
# 7
#
#                                                title
# 0                           The Upside of Unrequited
# 1                                Alex, Approximately
# 2                                         Geekerella
# 3            Twist\n      \n          (Dive  Bar #2)
# 4                                     Alex and Eliza
# 5  Defy the Stars\n      \n          (Constellati...
# 6                               The Thing About Love
# 7  Spindle Fire\n      \n          (Spindle Fire #1)
